# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Create a DataFrame

# %%
df_books=pd.read_csv('/home/dev16/Documents/bestsellers with categories.csv')

# %%
df_books.shape
# Out:
# (550, 7)

# %%
df_books.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %% [markdown]
# # Display the DataFrame

# %%
# shows first 5 rows in a dataframe
df_books.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df_books.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df_books.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %% [markdown]
# # Adding a new column with an array

# %%
critic_rating=np.random.randint(1,5,550)

# %%
df_books['Critic Rating']=critic_rating
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating
# 0              1
# 1              2
# 2              1
# 3              1
# 4              2

# %%
# reorder column with Critic rating between User Rating and Reviews
df_books=df_books[['Name','Author','User Rating','Critic Rating',
          'Reviews','Price','Year','Genre']]
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Critic Rating  Reviews  Price  \
# 0                    JJ Smith          4.7              1    17350      8
# 1                Stephen King          4.6              2     2052     22
# 2          Jordan B. Peterson          4.7              1    18979     15
# ...

# %%
df_books.head(10)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
# 8      A Higher Loyalty: Truth, Lies, and Leadership
# 9                          A Man Called Ove: A Novel
#
#                      Author  User Rating  Critic Rating  Reviews  Price  Year  \
# 0                  JJ Smith          4.7              1    17350      8  2016
# 1              Stephen King          4.6              2     2052     22  2011
# 2        Jordan B. Peterson          4.7              1    18979     15  2018
# ...

# %%
# df_books[['Name','Author']]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# ..                        ...
# 545               Jeff Kinney
# 546               Jen Sincero
# ...

# %%
df_books['Average Rating']=(df_books['User Rating']+df_books['Critic Rating'])/2
df_books['Average Rating'].round(1)
# Out:
# 0      2.8
# 1      3.3
# 2      2.8
# 3      2.8
# 4      3.4
#       ...
# 545    3.0
# 546    4.4
# 547    2.8
# 548    4.4
# 549    4.4
# Name: Average Rating, Length: 550, dtype: float64

# %% [markdown]
# # Value Counts

# %%
df_books['Genre'].value_counts(normalize=True)*100
# Out:
# Non Fiction    56.363636
# Fiction        43.636364
# Name: Genre, dtype: float64

# %% [markdown]
# # Rename Columns

# %%
df_books.rename(columns={'User Rating':'UR','Average Rating':'AR',
                        'Critic Rating':'CR'},inplace=True)
df_books.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author   UR  CR  Reviews  Price  Year        Genre    AR
# 0                  JJ Smith  4.7   1    17350      8  2016  Non Fiction  2.85
# 1              Stephen King  4.6   2     2052     22  2011      Fiction  3.30
# 2        Jordan B. Peterson  4.7   1    18979     15  2018  Non Fiction  2.85
# 3             George Orwell  4.7   1    21424      6  2017      Fiction  2.85
# 4  National Geographic Kids  4.8   2     7665     12  2019  Non Fiction  3.40

# %%
df_books=df_books[['Name','Author','UR','CR','AR','Year']]
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  CR    AR  Year
# 0                    JJ Smith  4.7   1  2.85  2016
# 1                Stephen King  4.6   2  3.30  2011
# 2          Jordan B. Peterson  4.7   1  2.85  2018
# 3               George Orwell  4.7   1  2.85  2017
# ...

# %%
df_books.sort_values(['UR','CR'],ascending=False,inplace=True)
df_books
# Out:
#                                                   Name                Author  \
# 146  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
# 187  Jesus Calling: Enjoying Peace in His Presence ...           Sarah Young
# 244                        Obama: An Intimate Portrait            Pete Souza
# 478                        The Very Hungry Caterpillar            Eric Carle
# 479                        The Very Hungry Caterpillar            Eric Carle
# ..                                                 ...                   ...
# 392  The Goldfinch: A Novel (Pulitzer Prize for Fic...           Donna Tartt
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 132                         Go Set a Watchman: A Novel            Harper Lee
# 353                                 The Casual Vacancy          J.K. Rowling
#
#       UR  CR    AR  Year
# ...

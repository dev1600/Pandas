# %% [markdown]
# # 1 Attributes

# %%
import pandas as pd

# %%
df_exams=pd.read_csv('/home/dev16/Downloads/StudentsPerformance.csv')

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
# getting access to the index attribute
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# getting acces to the column attribute
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# Generally when is says object it means string
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # 2 Methods

# %%
#showing info of the dataframe
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# Useful to get the basic statistical data
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # 3 Functions

# %%
# no of rows
len(df_exams)
# Out:
# 1000

# %%
#rounding the values of the dataset
round(df_exams,2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # 4 Selecting one column

# %%
# select a column with [] (preferred way to select a column)
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# check out the data type of a column
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# another way to select column (not preferred)
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %% [markdown]
# # 5 Select two or more columns

# %%
# select  2 columns using [[]]
df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
# select 2 or more columns using [[]]
df_exams[['gender','math score','reading score','writing score']]
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %% [markdown]
# # 6 Adding a new column

# %% [markdown]
# ## Adding a new column with a scalar value

# %%
# adding a new column to dataframe
df_exams['language score']=70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## Adding a new column with an array

# %%
# import numpy 
import numpy as np

# %%
# create an array of 1000 elements
language_score=np.arange(0,1000)

# %%
len(language_score)
# Out:
# 1000

# %%
# adding a new column to dataframe with an array
df_exams['language score']=language_score
# below is syntax to drop or delte a column 
# df_exams=df_exams.drop('language score',1)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
# create random integers number between 1 and 100
# first arg is inclusive and 2nd is exclusive
language_score=np.random.randint(1,100,size=1000)

# %%
df_exams['language score']=language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                19
# 1                56
# 2                23
# 3                71
# 4                85
# ..              ...
# 995              29
# 996              29
# 997              63
# 998              25
# 999              36
#
# [1000 rows x 9 columns]

# %%
# create random float numb ers between 1 and 100
np.random.uniform(1,100,size=1000)
# Out:
# array([40.63282097, 55.91777416, 99.38599048, 64.34607465, 41.41097394,
#        51.57920235, 23.63976778, 91.55730009,  9.73323046, 59.03168511,
#        90.83262775,  6.44043496, 25.24549911, 64.3000292 , 21.76698583,
#        40.72128262, 79.71165334, 60.57228121, 81.37693696, 34.5932959 ])

# %% [markdown]
# # 7 Math operations

# %% [markdown]
# ## Operations in column

# %%
# select a column and calculate total sum
df_exams['math score'].sum()
# Out:
# 66089

# %%
# count mean ,std, max and min
df_exams['math score'].count()
df_exams['math score'].mean()
df_exams['math score'].std()
df_exams['math score'].max()
df_exams['math score'].min()
# Out:
# 0

# %%
# describe method gives basic details
df_exams['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %% [markdown]
# # # Operations in rows

# %%
# calculating the sum in a row
df_exams['math score']+df_exams['reading score']+df_exams['writing score']+df_exams['language score']
# Out:
# 0      237
# 1      303
# 2      301
# 3      219
# 4      314
#       ...
# 995    311
# 996    201
# 997    258
# 998    248
# 999    285
# Length: 1000, dtype: int64

# %%
#calculating the average score and assigning to a new column
df_exams['average']=(df_exams['math score']+df_exams['reading score']+df_exams['writing score']+df_exams['language score'])/4
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  average
# 0                19    59.25
# 1                56    75.75
# 2                23    75.25
# 3                71    54.75
# 4                85    78.50
# ..              ...      ...
# 995              29    77.75
# 996              29    50.25
# 997              63    64.50
# 998              25    62.00
# 999              36    71.25
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## Value counts

# %%
# counting gender elements by category
df_exams['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# return the relative frequency (divide all values by the sum of values)
df_exams['gender'].value_counts(normalize=True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
# counting 'parental level of education' elements by category
df_exams['parental level of education'].value_counts(normalize=True)
# Out:
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: parental level of education, dtype: float64

# %% [markdown]
# # Sort a dataframe

# %%
# sort by one column
df_exams.sort_values(by='math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 59                     none           0             17             10
# 980                    none           8             24             23
# 17                     none          18             32             28
# 787                    none          19             38             32
# 145                    none          22             39             33
# ..                      ...         ...            ...            ...
# 625               completed         100             97             99
# 623               completed         100             96             86
# 451                    none         100             92             97
# 962                    none         100            100            100
# 149               completed         100            100             93
#
#      language score  average
# 59               62    22.25
# 980              60    28.75
# 17               38    29.00
# 787              58    36.75
# 145               1    23.75
# ..              ...      ...
# 625              17    78.25
# 623              60    85.50
# 451              40    82.25
# 962              80    95.00
# 149              29    80.50
#
# [1000 rows x 10 columns]

# %%
# sort descending by one column
df_exams.sort_values(by='math score',ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 962                    none         100            100            100
# 625               completed         100             97             99
# 458                    none         100            100            100
# 623               completed         100             96             86
# 451                    none         100             92             97
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  average
# 962              80    95.00
# 625              17    78.25
# 458              62    90.50
# 623              60    85.50
# 451              40    82.25
# ..              ...      ...
# 145               1    23.75
# 787              58    36.75
# 17               38    29.00
# 980              60    28.75
# 59               62    22.25
#
# [1000 rows x 10 columns]

# %%
# sort descending by multiple column
# order of column name give priority
# in this case math score > reading score 
df_exams.sort_values(['math score','reading score'],ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  average
# 149              29    80.50
# 458              62    90.50
# 916              27    81.75
# 962              80    95.00
# 625              17    78.25
# ..              ...      ...
# 145               1    23.75
# 787              58    36.75
# 17               38    29.00
# 980              60    28.75
# 59               62    22.25
#
# [1000 rows x 10 columns]

# %%
df_exams.sort_values(['math score','reading score'],ascending=False,
                    inplace=True)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  average
# 149              29    80.50
# 458              62    90.50
# 916              27    81.75
# 962              80    95.00
# 625              17    78.25
# ..              ...      ...
# 145               1    23.75
# 787              58    36.75
# 17               38    29.00
# 980              60    28.75
# 59               62    22.25
#
# [1000 rows x 10 columns]

# %%
# sort descending with a key function
df_exams.sort_values('race/ethnicity',ascending=True,
                    key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# 741                    none          37             57             56
# 151                    none          77             67             68
# 811                    none          45             47             49
# 112                    none          54             53             47
# 25                     none          73             74             72
# ..                      ...         ...            ...            ...
# 751                    none          68             72             65
# 915                    none          68             70             66
# 592                    none          68             68             64
# 479                    none          76             71             67
# 517               completed          66             74             73
#
#      language score  average
# 741              22    43.00
# 151              12    56.00
# 811              40    45.25
# 112              52    51.50
# 25               17    59.00
# ..              ...      ...
# 751              50    63.75
# 915              58    65.50
# 592              67    66.75
# 479              49    65.75
# 517              72    71.25
#
# [1000 rows x 10 columns]
